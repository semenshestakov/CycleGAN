# %%
import pandas as pd
import os

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'monet',
#  '__pycache__',
#  'data.csv',
#  '.ipynb_checkpoints',
#  'extract_data.py',
#  'photo',
#  'data.ipynb']

# %%
path = 'monet'
name = os.listdir(path)
df = pd.DataFrame({"name":name, "path":path})

path = 'photo'
name = os.listdir(path)
df2 = pd.DataFrame({"name":name, "path":path})

df = pd.concat([df,df2])
df.to_csv("data.csv")
df
# Out:
#                 name   path
# 0     1f22663e72.jpg  monet
# 1     50855dd324.jpg  monet
# 2     66a144f547.jpg  monet
# 3     463835bbc6.jpg  monet
# 4     2acfbab228.jpg  monet
# ...              ...    ...
# 7033  baa60c9bed.jpg  photo
# 7034  6fd674c2bc.jpg  photo
# 7035  b635c95844.jpg  photo
# 7036  6e8ec08b46.jpg  photo
# 7037  7e2ad883dd.jpg  photo
#
# [7338 rows x 2 columns]

# %%
for i in df.values:
    print(i)
# Out:
# ['1f22663e72.jpg' 'monet']
# ['50855dd324.jpg' 'monet']
# ['66a144f547.jpg' 'monet']
# ['463835bbc6.jpg' 'monet']
# ['2acfbab228.jpg' 'monet']
# ['6bfbd1df5b.jpg' 'monet']
# ['c7d8142152.jpg' 'monet']
# ['e753318d04.jpg' 'monet']
# ['4660310c3e.jpg' 'monet']
# ['990ed28f62.jpg' 'monet']
# ['632ddbc784.jpg' 'monet']
# ['058f878b7c.jpg' 'monet']
# ['8e5ff15568.jpg' 'monet']
# ['a030bc32e6.jpg' 'monet']
# ['de6f71b00f.jpg' 'monet']
# ['2cca56415e.jpg' 'monet']
# ['ec78d80dbd.jpg' 'monet']
# ['8077b7e9e7.jpg' 'monet']
# ['295eb5c521.jpg' 'monet']
# ['09b76b6471.jpg' 'monet']
# ['7d64c3100c.jpg' 'monet']
# ['79292e1434.jpg' 'monet']
# ['da72006ef5.jpg' 'monet']
# ['8044a92484.jpg' 'monet']
# ['6ee7c39dbc.jpg' 'monet']
# ['661e374153.jpg' 'monet']
# ['8cfd45a2e2.jpg' 'monet']
# ['c2576267d4.jpg' 'monet']
# ['a885da7b52.jpg' 'monet']
# ['608ee0d370.jpg' 'monet']
# ['fc11d52502.jpg' 'monet']
# ['3eaef3ee43.jpg' 'monet']
# ['910610e827.jpg' 'monet']
# ['f0d789c4bc.jpg' 'monet']
# ...
